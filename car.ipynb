# %%
import pandas as pd

# %%
data = pd.read_csv("car.txt")

# %%
data.to_csv("car.csv")

# %%
data
# Out:
#      3    ?  alfa-romero     gas    std   two  convertible  rwd  front  88.60  \
# 0    3    ?  alfa-romero     gas    std   two  convertible  rwd  front   88.6
# 1    1    ?  alfa-romero     gas    std   two    hatchback  rwd  front   94.5
# 2    2  164         audi     gas    std  four        sedan  fwd  front   99.8
# 3    2  164         audi     gas    std  four        sedan  4wd  front   99.4
# 4    2    ?         audi     gas    std   two        sedan  fwd  front   99.8
# ..  ..  ...          ...     ...    ...   ...          ...  ...    ...    ...
# 199 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 200 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
# 201 -1   95        volvo     gas    std  four        sedan  rwd  front  109.1
# 202 -1   95        volvo  diesel  turbo  four        sedan  rwd  front  109.1
# 203 -1   95        volvo     gas  turbo  four        sedan  rwd  front  109.1
#
#      ...  130  mpfi  3.47  2.68  9.00  111  5000  21  27  13495
# 0    ...  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1    ...  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2    ...  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3    ...  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4    ...  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
# ..   ...  ...   ...   ...   ...   ...  ...   ...  ..  ..    ...
# 199  ...  141  mpfi  3.78  3.15   9.5  114  5400  23  28  16845
# 200  ...  141  mpfi  3.78  3.15   8.7  160  5300  19  25  19045
# 201  ...  173  mpfi  3.58  2.87   8.8  134  5500  18  23  21485
# 202  ...  145   idi  3.01  3.40  23.0  106  4800  26  27  22470
# 203  ...  141  mpfi  3.78  3.15   9.5  114  5400  19  25  22625
#
# [204 rows x 26 columns]

# %%
cols = ['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration', 'num-of-doors', 'body-style', 'drive-wheels', 'engine-location', 'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type', 'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke', 'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg', 'highway-mpg', 'price']
data = pd.read_csv('car.csv', names=cols)
print(data.shape)
data.head()
# Out:
# (205, 26)
#      symboling normalized-losses         make fuel-type aspiration  \
# NaN          3                 ?  alfa-romero       gas        std
# 0.0          3                 ?  alfa-romero       gas        std
# 1.0          1                 ?  alfa-romero       gas        std
# 2.0          2               164         audi       gas        std
# 3.0          2               164         audi       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# NaN          two  convertible          rwd           front        88.6  ...
# 0.0          two  convertible          rwd           front        88.6  ...
# 1.0          two    hatchback          rwd           front        94.5  ...
# 2.0         four        sedan          fwd           front        99.8  ...
# 3.0         four        sedan          4wd           front        99.4  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# NaN          130         mpfi  3.47    2.68               9.0        111
# 0.0          130         mpfi  3.47    2.68               9.0        111
# 1.0          152         mpfi  2.68    3.47               9.0        154
# 2.0          109         mpfi  3.19    3.40              10.0        102
# 3.0          136         mpfi  3.19    3.40               8.0        115
#
#      peak-rpm city-mpg highway-mpg  price
# NaN      5000       21          27  13495
# 0.0      5000       21          27  16500
# 1.0      5000       19          26  16500
# 2.0      5500       24          30  13950
# 3.0      5500       18          22  17450
#
# [5 rows x 26 columns]

# %%
import numpy as np
data = data.replace("?", np.NaN)
data.head()
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# NaN          3               NaN  alfa-romero       gas        std
# 0.0          3               NaN  alfa-romero       gas        std
# 1.0          1               NaN  alfa-romero       gas        std
# 2.0          2               164         audi       gas        std
# 3.0          2               164         audi       gas        std
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# NaN          two  convertible          rwd           front        88.6  ...
# 0.0          two  convertible          rwd           front        88.6  ...
# 1.0          two    hatchback          rwd           front        94.5  ...
# 2.0         four        sedan          fwd           front        99.8  ...
# 3.0         four        sedan          4wd           front        99.4  ...
#
#      engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# NaN          130         mpfi  3.47    2.68               9.0        111
# 0.0          130         mpfi  3.47    2.68               9.0        111
# 1.0          152         mpfi  2.68    3.47               9.0        154
# 2.0          109         mpfi  3.19    3.40              10.0        102
# 3.0          136         mpfi  3.19    3.40               8.0        115
#
#      peak-rpm city-mpg highway-mpg  price
# NaN      5000       21          27  13495
# 0.0      5000       21          27  16500
# 1.0      5000       19          26  16500
# 2.0      5500       24          30  13950
# 3.0      5500       18          22  17450
#
# [5 rows x 26 columns]

# %%
data.isnull().any().any()
# Out:
# True

# %%
data.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64
